# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import re as regex

# %% [markdown]
# Bock,R.. (2007). MAGIC Gamma Telescope. UCI Machine Learning Repository. https://doi.org/10.24432/C52C8B.

# %%
data = '''    1.  fLength:  continuous  # major axis of ellipse [mm]
    2.  fWidth:   continuous  # minor axis of ellipse [mm] 
    3.  fSize:    continuous  # 10-log of sum of content of all pixels [in #phot]
    4.  fConc:    continuous  # ratio of sum of two highest pixels over fSize  [ratio]
    5.  fConc1:   continuous  # ratio of highest pixel over fSize  [ratio]
    6.  fAsym:    continuous  # distance from highest pixel to center, projected onto major axis [mm]
    7.  fM3Long:  continuous  # 3rd root of third moment along major axis  [mm] 
    8.  fM3Trans: continuous  # 3rd root of third moment along minor axis  [mm]
    9.  fAlpha:   continuous  # angle of major axis with vector to origin [deg]
   10.  fDist:    continuous  # distance from origin to center of ellipse [mm]
   11.  class:    g,h         # gamma (signal), hadron (background)'''
lines = data.split('\n')
reg_exp = "[^:\s]*(?=:)"

columns =[regex.search(reg_exp,line, regex.IGNORECASE).group(0) for line in lines]

df = pd.read_csv("magic04.data",names=columns)
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %% [markdown]
# Hello, My name is Jawad Alhamadah, a web developer interested in your company. I have experience in React and Node.js, and I noticed that this is the main focus of your company, and I believe I can be a good fit.
# I graduated from K-State University in the United States of America with a computer science degree. Soon after, I completed a nano degree in machine learning offered by MISK and SDAIA.
# I also completed a training program at King Abdullah's International Medical Research Center in Riyadh.
# Personal projects include: 1 - A dog breed classifier using React and machine learning in Python. 2 - A collaborative painting app using Socket.io, Node.js, and JavaScript. 3 - An XML to XML data conglomeration tool using Express and MongoDB as a database.
# Here is my resume: Thank you for your consideration.
#
#
# Technology Control Co. = angular, spring boot
#
# ELM - MEAN , Anuglar,  Spring boot
#
# LeanNode : MERN , Nodejs , react

# %%
df["class"] =(df["class"]=="g").astype(int)
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist  class
# 0  40.0920   81.8828      1
# 1   6.3609  205.2610      1
# 2  76.9600  256.7880      1
# 3  10.4490  116.7370      1
# 4   4.6480  356.4620      1
